# %% [markdown]
# # Dynamic Light Scattering Experiment

# %%
import sys
sys.path.append("..")
from sicm.sicm import ZetaSizerReader

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
datadir = "/run/user/1000/gvfs/smb-share:server=itet-stor.ee.ethz.ch,share=mholub/sicm/UsersData/Martin/2019/03_Mar/20/ZetaSizer/TiNSiO2_SDS.txt"
datadir = r"S:\UsersData\Martin\2019\03_Mar\20\ZetaSizer"
exp_name = r"TiNSiO2_SDS"
zsr = ZetaSizerReader(datadir, exp_name)
dls_array = zsr.load_measurements()
len(dls_array)
# Out:
# 4

# %%
# Watch out, data sometimes contains more samples than expected!
# Plots by number and volume are most sensible.
dls_array[-1].plot(scale = "logx")
# Out:
# Saved figure to S:\UsersData\Martin\2019\03_Mar\20\ZetaSizer\TiNSiO2_SDS_SDS+TiNSiO2_91_sio2SOP_Volumes.

# %%
print((220.2 + 220.2 + 220.2) / 3)
print((122.5 + 120.3 + 108.7) / 3)
print((43.9 + 49.4 + 48.8)/3)
# Out:
# 220.19999999999996
# 117.16666666666667
# 47.36666666666667

# %%
print((190.1 + 190.1 + 220.2) / 3)
print((95.55 + 86.68 + 107.8) / 3)
print((41.8 + 38.9 + 45.1)/3)
# Out:
# 200.13333333333333
# 96.67666666666668
# 41.93333333333333
