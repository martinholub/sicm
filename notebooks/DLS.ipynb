# %% [markdown]
# # Dynamic Light Scattering Experiment

# %%
import sys
sys.path.append("..")
from sicm.sicm import ZetaSizerReader

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
zsr = ZetaSizerReader("/run/user/1000/gvfs/smb-share:server=itet-stor.ee.ethz.ch,share=mholub/sicm/UsersData/Martin/2019/03_Mar/20/ZetaSizer/TiNSiO2_SDS.txt")
dls_array = zsr.load_measurements()

# %%
# Watch out, data sometimes contains more samples than expected!
# Plots by number and volume are most sensible.
dls_array[3].plot("Volumes")
# Out:
# Saved figure to /run/user/1000/gvfs/smb-share:server=itet-stor.ee.ethz.ch,share=mholub/sicm/UsersData/Martin/2019/03_Mar/20/ZetaSizer/TiNSiO2_SDS_SDS+TiNSiO2_91_sio2SOP_Volumes.pdf.
